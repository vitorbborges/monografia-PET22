# %%
import warnings
warnings.filterwarnings("ignore")

from gensim.models import ldamodel

from datetime import datetime, timedelta
import numpy as np
import pandas as pd
from tqdm import tqdm
from scipy.stats import entropy
import ruptures as rpt

import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.tight_layout()
plt.style.use('seaborn-v0_8-darkgrid')

plt.rcParams['figure.figsize'] = (10, 5)

from utils import dataset, load_bow

# %%
col = [
    'Publication Type', \
    'Venue', \
    'Author Full Names', \
    'Article Title', \
    'Abstract', \
    'Publication Date', \
    'Publication Year']

venues = dataset()[col]
venues = venues.dropna(subset=['Abstract'])
venues['Abstract Lemmatized'] = load_bow('25_venues')
venues = venues.dropna(subset=['Publication Date'])
venues['Date'] = (venues['Publication Date']+'-'+venues['Publication Year']).apply(lambda x: datetime.strptime(x, '%b-%Y'))
venues = venues.sort_values(by='Date')
venues.index = range(len(venues))

# %%
model_name = '60_asymmetric_auto_0.5_0.0075'
model = ldamodel.LdaModel.load(f'models/lda_models/{model_name}')

# %%
def get_topics(bow):
    return model.get_document_topics(model.id2word.doc2bow(bow), minimum_probability=0)
venues['LDA Distribution'] = venues['Abstract Lemmatized'].apply(lambda x: get_topics(x))

# %%
df = venues[['Date', 'Venue', 'LDA Distribution']]
date_dict = {pd.Timestamp(i): (df['Date'][df['Date'] == i].index[0], df['Date'][df['Date'] == i].index[-1]) for i in df['Date'].unique()}

# %%
topic_df = pd.read_csv('models/topics.csv')
topic_df
# Out:
#     Topics                                             Labels  \
# 0        0                Graph Theory and Network Structures
# 1        1                Control Systems and Dynamic Systems
# 2        2                      Systems and Energy Management
# 3        3       Multi-level Feature Fusion and Deep Learning
# 4        4  Probability Distribution and Estimation Algori...
# 5        5            Evolutionary Algorithm and Optimization
# 6        6                  Urban Navigation and Localization
# 7        7             Object Recognition and Visual Saliency
# 8        8                                   Object Detection
# 9        9              Cybersecurity & Network Communication
# 10      10                Information Retrieval & Data Mining
# 11      11                    Image Processing and Resolution
# 12      12           Relational Data and Entity Relationships
# 13      13               Failure Diagnosis and Causal Effects
# 14      14               Medical Diagnosis and Patient Health
# 15      15            Neural Network and Synaptic Functioning
# 16      16    Time Series Forecasting and Prediction Modeling
# 17      17              Camera Tracking and Motion Estimation
# 18      18                         Bias and Evidence Analysis
# 19      19                 Game Theory and Strategic Behavior
# 20      20                Facial Recognition & Identification
# 21      21             Computational Efficiency & Performance
# 22      22                      Shape and Gesture Recognition
# 23      23                    Semantic Word Embeddings in NLP
# 24      24                Reinforcement Learning and Robotics
# 25      25                    Human Attributes & Interactions
# 26      26                               Deep Neural Networks
# 27      27                            Expert Systems & Design
# 28      28                     Regression Analysis & Modeling
# 29      29              Information Imputation and Completion
# 30      30                        Constraint Planning & Logic
# 31      31                     Feature Extraction & Selection
# 32      32                    Adversarial Generative Modeling
# 33      33                     Sentiment and Emotion Analysis
# 34      34                 Probabilistic Modeling & Inference
# 35      35                      Social Recommendation Systems
# 36      36                       Classification & Performance
# 37      37              Multi-Dimensional Data Representation
# 38      38                                   Robust Denoising
# 39      39                     Data Clustering & Segmentation
# 40      40              Image Partitioning & Texture Analysis
# 41      41                       Decision Making & Evaluation
# 42      42                       Speech & Language Processing
# 43      43              Domain Adaptation & Transfer Learning
# 44      44                    Semi-Supervised Data Annotation
# 45      45                 Modeling with Attention Mechanisms
# 46      46                                      Deep Learning
# 47      47                                  Signal Processing
# 48      48                           Video Action Recognition
# 49      49                             Document Summarization
# 50      50                   Similarity Measures and Rankings
# 51      51                    Research and Development Trends
# 52      52                                Fuzzy Logic Systems
# 53      53                           Fuzzy Value & Set Theory
# 54      54                  Linear and Nonlinear Optimization
# 55      55                          Financial Markets & Risks
# 56      56                   Adaptive optimization algorithms
# 57      57                         Class Imbalance & Sampling
# 58      58                    Data Management and Utilization
# 59      59                     Optimization & Problem-Solving
#
#                Groups                                              Terms
# 0            Networks  0.134*"graph" + 0.075*"structure" + 0.066*"nod...
# 1   Systems & Control  0.050*"control" + 0.039*"system" + 0.026*"time...
# 2   Systems & Control  0.043*"system" + 0.019*"power" + 0.014*"time" ...
# 3                  DL  0.024*"multi" + 0.020*"level" + 0.019*"feature...
# 4          Statistics  0.030*"distribution" + 0.020*"algorithm" + 0.0...
# 5             Genetic  0.065*"algorithm" + 0.032*"optimization" + 0.0...
# 6          Navigation  0.053*"location" + 0.027*"trajectory" + 0.023*...
# 7                  CV  0.162*"object" + 0.069*"visual" + 0.033*"image...
# 8                  CV  0.201*"detection" + 0.077*"detect" + 0.031*"de...
# 9       Cybersecurity  0.050*"event" + 0.037*"attack" + 0.035*"servic...
# 10                NLP  0.069*"pattern" + 0.047*"query" + 0.038*"searc...
# 11                 CV  0.035*"surface" + 0.026*"resolution" + 0.026*"...
# 12         Statistics  0.147*"group" + 0.142*"relation" + 0.066*"enti...
# 13              Fault  0.077*"fault" + 0.065*"effect" + 0.043*"variab...
# 14                Med  0.033*"diagnosis" + 0.032*"patient" + 0.031*"m...
# 15                 DL  0.066*"neuron" + 0.029*"spike" + 0.027*"mechan...
# 16         Statistics  0.108*"prediction" + 0.070*"time" + 0.052*"ser...
# 17                 CV  0.026*"camera" + 0.019*"tracking" + 0.017*"poi...
# 18         Statistics  0.072*"bias" + 0.063*"evidence" + 0.036*"hypot...
# 19    Decision Making  0.102*"strategy" + 0.074*"game" + 0.027*"play"...
# 20                 CV  0.106*"face" + 0.077*"recognition" + 0.033*"im...
# 21         Complexity  0.033*"time" + 0.028*"large" + 0.022*"computat...
# 22                 CV  0.072*"shape" + 0.050*"recognition" + 0.019*"h...
# 23                NLP  0.081*"word" + 0.081*"semantic" + 0.030*"sente...
# 24                 RL  0.072*"agent" + 0.041*"policy" + 0.032*"enviro...
# 25                 RL  0.136*"human" + 0.100*"attribute" + 0.058*"cel...
# 26                 DL  0.235*"network" + 0.128*"neural" + 0.033*"laye...
# 27                 ES  0.064*"system" + 0.051*"knowledge" + 0.022*"de...
# 28         Statistics  0.034*"error" + 0.033*"regression" + 0.025*"mo...
# 29                 ML  0.473*"information" + 0.037*"miss" + 0.025*"mu...
# 30                NaN  0.019*"constraint" + 0.018*"path" + 0.014*"sho...
# 31                 ML  0.354*"feature" + 0.043*"extract" + 0.042*"sel...
# 32                 DL  0.037*"generate" + 0.033*"model" + 0.024*"gene...
# 33                NLP  0.027*"model" + 0.026*"dataset" + 0.024*"senti...
# 34         Statistics  0.398*"model" + 0.018*"parameter" + 0.018*"pro...
# 35     Recommendation  0.108*"user" + 0.030*"recommendation" + 0.030*...
# 36                 ML  0.084*"classification" + 0.048*"classifier" + ...
# 37         Statistics  0.054*"space" + 0.050*"representation" + 0.043...
# 38         Statistics  0.126*"noise" + 0.071*"loss" + 0.059*"robust" ...
# 39                 ML  0.116*"cluster" + 0.069*"clustering" + 0.063*"...
# 40                 CV  0.232*"image" + 0.055*"segmentation" + 0.032*"...
# 41           Business  0.064*"decision" + 0.034*"criterion" + 0.023*"...
# 42                NLP  0.063*"language" + 0.047*"code" + 0.038*"trans...
# 43                 ML  0.233*"domain" + 0.172*"target" + 0.085*"sourc...
# 44                 ML  0.151*"label" + 0.031*"datum" + 0.023*"trainin...
# 45                 DL  0.074*"sequence" + 0.062*"attention" + 0.039*"...
# 46                 DL  0.096*"learning" + 0.054*"learn" + 0.051*"task...
# 47  Signal Processing  0.076*"signal" + 0.033*"phase" + 0.028*"brain"...
# 48                 CV  0.114*"video" + 0.061*"temporal" + 0.046*"acti...
# 49                NLP  0.087*"document" + 0.086*"topic" + 0.048*"cont...
# 50      Biostatistics  0.104*"measure" + 0.095*"similarity" + 0.071*"...
# 51                 RD  0.029*"research" + 0.022*"study" + 0.017*"anal...
# 52              Fuzzy  0.223*"fuzzy" + 0.103*"rule" + 0.086*"system" ...
# 53              Fuzzy  0.054*"value" + 0.047*"set" + 0.025*"weight" +...
# 54              Optim  0.039*"function" + 0.034*"matrix" + 0.021*"lin...
# 55           Business  0.035*"risk" + 0.031*"market" + 0.028*"student...
# 56              Optim  0.090*"algorithm" + 0.051*"parameter" + 0.030*...
# 57                 ML  0.115*"class" + 0.114*"sample" + 0.030*"instan...
# 58               Data  0.220*"datum" + 0.060*"data" + 0.019*"set" + 0...
# 59              Optim  0.095*"problem" + 0.047*"algorithm" + 0.041*"s...

# %% [markdown]
# # TOPIC FREQUENCE TRENDS

# %%
for K in range(60):
    df[f'Topic {K}'] = df['LDA Distribution'].apply(lambda x: x[K][1] if K in [y[0] for y in x] else 0)

# %%
data = df.groupby('Date').sum()/df.groupby('Date').count()
data = data.drop(columns=['LDA Distribution', 'Venue'])
data_norm = data/data.iloc[0]

# %%
rolling_data = data.rolling(12).mean().dropna()
rolling_data_norm = rolling_data/rolling_data.iloc[0]

# %%
K = 48

vals = pd.DataFrame(rolling_data[f'Topic {K}'])
time = np.arange(len(vals)).reshape(-1, 1)
time = sm.add_constant(time)
results = sm.OLS(vals, time).fit()
vals['predicted'] = results.predict(time)

plt.plot(vals)
plt.legend(vals)
plt.show()

# %%
topic_df.loc[K]['Labels']
# Out:
# 'Video Action Recognition'

# %%
K = 8, 20, 48

vals = pd.DataFrame(rolling_data_norm[f'Topic {K}'])
time = np.arange(len(vals)).reshape(-1, 1)
time = sm.add_constant(time)
results = sm.OLS(vals, time).fit()
vals['predicted'] = results.predict(time)

plt.plot(vals)
plt.legend([topic_df.loc[K]['Labels'], 'predicted'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\vitor\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File c:\Users\vitor\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\vitor\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Topic (8, 20, 48)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\vitor\Desktop\Education\PET\MONOGRAFIA 2022\monografia-PET22\Topic Trends.ipynb Cell 13 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/vitor/Desktop/Education/PET/MONOGRAFIA%202022/monografia-PET22/Topic%20Trends.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> K = 8, 20, 48
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vitor/Desktop/Education/PET/MONOGRAFIA%202022/monografia-PET22/Topic%20Trends.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> vals = pd.DataFrame(rolling_data_norm[f'Topic {K}'])
#       <a href='vscode-notebook-cell:/c%3A/Users/vitor/Desktop/Education/PET/MONOGRAFIA%202022/monografia-PET22/Topic%20Trends.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> time = np.arange(len(vals)).reshape(-1, 1)
#       <a href='vscode-notebook-cell:/c%3A/Users/vitor/Desktop/Education/PET/MONOGRAFIA%202022/monografia-PET22/Topic%20Trends.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> time = sm.add_constant(time)
#
# File c:\Users\vitor\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File c:\Users\vitor\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'Topic (8, 20, 48)'

# %%
coefs = []

for K in range(60):
    vals = pd.DataFrame(data[f'Topic {K}'])
    time = np.arange(len(vals)).reshape(-1, 1)
    time = sm.add_constant(time)
    results = sm.OLS(vals, time).fit()
    coefs.append((K, results.params[1], results.pvalues[1]))

largest = sorted(coefs, key=lambda x: x[1], reverse=True)[:3]
largest = list(map(lambda x: x[0], largest))
print('largest: ', largest)
smallest = sorted(coefs, key=lambda x: x[1])[:3]
smallest = list(map(lambda x: x[0], smallest))
print('smallest: ', smallest)
# Out:
# largest:  [3, 46, 5]
# smallest:  [27, 17, 30]

# %%
largest = list(map(lambda x: int(x[-2:]), rolling_data_norm.T.sort_values(by='2023-04-01', ascending=False).head(3).index))
print('largest: ', largest)
smallest = list(map(lambda x: int(x[-2:]), rolling_data_norm.T.sort_values(by='2023-04-01', ascending=True).head(3).index))
print('smallest: ', smallest)
# Out:
# largest:  [3, 46, 35]
# smallest:  [11, 17, 30]

# %%
# DL: plot = [3, 46, 15, 26, 32, 45]
# CV: plot = [7, 8, 11, 17, 20, 22, 40, 48]

plot = [24]
series = rolling_data[[f'Topic {i}' for i in plot]]

plt.plot(series)
plt.legend(topic_df.iloc[plot]['Labels'])
plt.xlabel('Year')
plt.ylabel('Topic Frequency')
plt.show()

# %%
min(series['Topic 27'])
# Out:
# 0.015321603869131591

# %%
plot = [23]
series = rolling_data[[f'Topic {i}' for i in plot]]

plt.plot(series)
plt.legend(topic_df.iloc[plot]['Labels'])
plt.xlabel('Year')
plt.ylabel('Topic Frequency')
plt.show()

# %%
topic_names = pd.read_csv('models/topics.csv')['Labels']


for K in range(60):
    series = rolling_data[[f'Topic {K}']]
    plt.plot(series, label=topic_names.loc[K])
    plt.legend()
    plt.xlabel('Year')
    plt.ylabel('Topic Frequency')
    plt.savefig(f'plots/topic_trends/{topic_names.loc[K]}.png')
    plt.clf()

# %% [markdown]
# # Topic Entropy Over Time

# %%
venues['LDA Distribution'] = df['LDA Distribution']
venues['entropy'] = [entropy([i[1] for i in x]) for x in venues['LDA Distribution']]
entropy_df = (venues.groupby('Date')['entropy'].sum()/venues.groupby('Date')['entropy'].count()).rolling(30).mean().dropna()

# %%
entropy_df = (venues.groupby('Date')['entropy'].sum()/venues.groupby('Date')['entropy'].count()).rolling(36).mean().dropna()
plt.plot(entropy_df)
plt.ylim(1.8, 2)

model = "rbf"
algo = rpt.Pelt(model=model).fit(entropy_df.values)
result = algo.predict(pen=15)

for i in range(1, len(result)):
    segment = entropy_df.iloc[result[i-1]:result[i]]
    if segment.mean() > segment.iloc[0]:
        plt.vlines(segment.idxmax(), 1.85, 1.975, color='red', linestyles='dashed', alpha=0.5)
        plt.annotate(f'{segment.idxmax().month}-{segment.idxmax().year}', (segment.idxmax()-timedelta(days=11*30), 1.8375))
    elif segment.mean() < segment.iloc[0]:
        plt.vlines(segment.idxmin(), 1.85, 1.975, color='red', linestyles='dashed', alpha=0.5)
        plt.annotate(f'{segment.idxmin().month}-{segment.idxmin().year}', (segment.idxmin()-timedelta(days=11*30), 1.8375))

plt.xlabel('Year')
plt.ylabel('Entropy')
plt.show()

# %%
data.iloc[np.where(data.index < '2001-10-01')].mean(axis=0).sort_values(ascending=False).head(10)
# Out:
# Topic 27    0.105494
# Topic 17    0.056722
# Topic 26    0.040804
# Topic 30    0.038770
# Topic 1     0.036273
# Topic 54    0.036256
# Topic 4     0.035277
# Topic 51    0.032908
# Topic 11    0.030239
# Topic 22    0.029634
# dtype: float64

# %%
data.iloc[np.where((data.index > '2001-10-01') & (data.index < '2016-07-01'))].mean(axis=0).sort_values(ascending=False).head(10)
# Out:
# Topic 1     0.051803
# Topic 27    0.044082
# Topic 59    0.041269
# Topic 36    0.038803
# Topic 51    0.037026
# Topic 17    0.035428
# Topic 4     0.032656
# Topic 2     0.029310
# Topic 54    0.028467
# Topic 21    0.027344
# dtype: float64

# %%
data.iloc[np.where(data.index > '2016-07-01')].mean(axis=0).sort_values(ascending=False).head(10)
# Out:
# Topic 1     0.049701
# Topic 3     0.043409
# Topic 46    0.042728
# Topic 59    0.037932
# Topic 51    0.034262
# Topic 4     0.032896
# Topic 21    0.032011
# Topic 5     0.031659
# Topic 36    0.028712
# Topic 26    0.028104
# dtype: float64

# %%
data.mean(axis=0).sort_values(ascending=False).head(10)
# Out:
# Topic 27    0.059206
# Topic 1     0.046346
# Topic 17    0.038307
# Topic 59    0.036706
# Topic 51    0.035064
# Topic 4     0.033495
# Topic 26    0.031410
# Topic 54    0.030231
# Topic 36    0.030020
# Topic 21    0.028052
# dtype: float64

# %%
top_entropy_venues = venues[['Date', 'Venue', 'entropy']].groupby('Venue').mean().sort_values(by='entropy', ascending=False).head(3)
top_entropy_venues
# Out:
#              entropy
# Venue
# IEEE-TPAMI  2.000494
# ICCV        1.989416
# IEEE-CVPR   1.982580

# %%
bottom_entropy_venues = venues[['Date', 'Venue', 'entropy']].groupby('Venue').mean().sort_values(by='entropy', ascending=False).tail(3)
bottom_entropy_venues
# Out:
#              entropy
# Venue
# IEEE-TNNLS  1.825559
# AISTATS     1.801023
# IEEE-TFS    1.671213

# %%
t = pd.DataFrame(index=range(60))
t['entropy'] = np.nan
for i in range(60):
    t.loc[i, 'entropy'] = entropy(list(map(lambda x: x[1], model.get_topic_terms(i, topn=1000000))))
t.sort_values(by='entropy', ascending=False)
# Out:
#      entropy
# 2   6.642777
# 4   6.320067
# 30  6.277323
# 51  6.209116
# 33  6.197311
# 17  6.186669
# 54  6.064210
# 32  6.018433
# 27  6.016147
# 11  6.014730
# 14  5.892074
# 28  5.890030
# 6   5.885887
# 3   5.878331
# 22  5.856991
# 15  5.848541
# 9   5.829209
# 35  5.798581
# 41  5.792938
# 1   5.765493
# 21  5.746646
# 5   5.727166
# 47  5.721585
# 18  5.700657
# 53  5.693843
# 55  5.676433
# 24  5.642884
# 23  5.563900
# 42  5.519065
# 46  5.471260
# 19  5.448763
# 36  5.447528
# 37  5.447305
# 56  5.435641
# 59  5.431109
# 10  5.403150
# 16  5.327183
# 49  5.312470
# 44  5.279603
# 7   5.243182
# 20  5.240288
# 13  5.217875
# 0   5.193582
# 57  5.180477
# 39  5.159106
# 38  5.122006
# 58  5.096854
# 45  5.095896
# 8   5.072213
# 40  5.045323
# 48  5.018714
# 50  5.009868
# 25  4.962306
# 12  4.610695
# 26  4.513916
# 52  4.379582
# 34  4.291666
# 31  4.157922
# 43  3.655128
# 29  3.620050

# %% [markdown]
# # Topic Groups Trends

# %%
groups = topic_df.groupby('Groups').count().sort_values(by='Labels', ascending=False).head(3).index

# %%
topic_df.iloc[topic_df[topic_df['Groups'] == 'Fuzzy']['Topics'].values]['Labels']
# Out:
# 52         Fuzzy Logic Systems
# 53    Fuzzy Value & Set Theory
# Name: Labels, dtype: object

# %%
groups = ['CV', 'DL']
groups = ['RL']

for g in groups:
    series = rolling_data[[f'Topic {t}' for t in topic_df[topic_df['Groups'] == g]['Topics'].values]]
    series['sum'] = series.sum(axis=1)
    plt.plot(series['sum'])

plt.legend(['Computer Vision Group', 'Deep Learning Group'])
plt.ylim(0, 0.1)
plt.xlabel('Year')
plt.ylabel('Topic Group Frequency')
plt.show()

# %%
A = rolling_data[[f'Topic {t}' for t in topic_df[topic_df['Groups'] == 'CV']['Topics'].values]]
A['mean'] = A.sum(axis=1)
cv = A['mean']

B = rolling_data[[f'Topic {t}' for t in topic_df[topic_df['Groups'] == 'DL']['Topics'].values]]
B['mean'] = B.sum(axis=1)
dl = B['mean']

from scipy.stats import pearsonr
corr, p = pearsonr(cv, dl)
print('Pearsons correlation: %.5f' % corr)
print('p-value: %.3f' % p)
# Out:
# Pearsons correlation: -0.61749
# p-value: 0.000

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Calculate the sum of frequencies per group
group_sums = {}
for group in topic_df['Groups'].unique():
    series = rolling_data[[f'Topic {t}' for t in topic_df[topic_df['Groups'] == group]['Topics'].values]]
    group_sums[group] = series.sum().sum()

# Rank the groups based on the average sum of frequencies
group_ranks = sorted(group_sums.items(), key=lambda x: x[1], reverse=True)
top_groups = [group for group, _ in group_ranks[:10]]

series_list = []
labels = []

for g in top_groups:
    series = rolling_data[[f'Topic {t}' for t in topic_df[topic_df['Groups'] == g]['Topics'].values]]
    series_sum = series.sum(axis=1)
    series_list.append(series_sum)
    labels.append(g)

# Add an "Others" group for non-top groups
other_series = rolling_data[[f'Topic {t}' for t in topic_df[~topic_df['Groups'].isin(top_groups)]['Topics'].values]].sum(axis=1)
series_list.append(other_series)
labels.append("Others")

# Transpose the series_list
series_array = np.column_stack(series_list)

# Create the stacked area plot with alpha for better visualization
plt.stackplot(range(len(series_array)), series_array.T, labels=labels, alpha=0.7)

# Change xticks to display dates
date_range = pd.date_range(rolling_data.index.min(), rolling_data.index.max(), freq='Y')
#plt.xticks(range(0, len(series_array), len(series_array) // len(date_range)), date_range.strftime('%Y'))

plt.legend()
plt.xlabel('Year')
plt.ylabel('Average Topic Frequency')
plt.show()
