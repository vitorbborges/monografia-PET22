# %%
import urllib.request as libreq
import json
import pandas as pd
from bs4 import BeautifulSoup
import requests
import tqdm
import os
import glob

# %%
df = pd.DataFrame()

# %%
year = '2013'
with libreq.urlopen(f'https://dblp.uni-trier.de/search/publ/api?q=stream%3Aconf%2Ficlr%3A%20year%3A{year}%3A&h=1000&format=json') as url:
    r = url.read()
    data_json = json.loads(r)

# %%
[title['info']['title'] for title in data_json['result']['hits']['hit']]
# Out:
# ['Local Component Analysis',
#  'When Does a Mixture of Products Contain a Product of Mixtures?',
#  'Linear-Nonlinear-Poisson Neurons Can Do Inference On Deep Boltzmann Machines',
#  'Regularized Auto-Encoders Estimate Local Statistics',
#  'Visual Objects Classification with Sliding Spatial Pyramid Matching',
#  'Cutting Recursive Autoencoder Trees',
#  'Clustering Learning for Robotic Vision',
#  'Unsupervised Feature Learning for low-level Local Image Descriptors',
#  'Matrix Approximation under Local Low-Rank Assumption',
#  'The Manifold of Human Emotions',
#  'Efficient Learning of Domain-invariant Image Representations',
#  'Auto-pooling: Learning to Improve Invariance of Image Features from Image Sequences',
#  'Barnes-Hut-SNE',
#  'The Diagonalized Newton Algorithm for Nonnegative Matrix Factorization',
#  'Feature grouping from spatially constrained multiplicative interaction',
#  'Factorized Topic Models',
#  'Boltzmann Machines and Denoising Autoencoders for Image Denoising',
#  'Pushing Stochastic Gradient towards Second-Order Methods -- Backpropagation Learning with Transformations in Nonlinearities',
#  'A Semantic Matching Energy Function for Learning with Multi-relational Data',
#  'Learnable Pooling Regions for Image Classification',
#  'Block Coordinate Descent for Sparse NMF',
#  'Discrete Restricted Boltzmann Machines',
#  'The Neural Representation Benchmark and its Evaluation on Brain and Machine',
#  'Learning Stable Group Invariant Representations with Convolutional Networks',
#  'Learning Features with Structure-Adapting Multi-view Exponential Family Harmoniums',
#  'Deep Predictive Coding Networks',
#  'Metric-Free Natural Gradient for Joint-Training of Boltzmann Machines',
#  'Information Theoretic Learning with Infinitely Divisible Kernels',
#  'Stochastic Pooling for Regularization of Deep Convolutional Neural Networks',
#  'Complexity of Representation and Inference in Compositional Models with Part Sharing',
#  'Joint Training Deep Boltzmann Machines for Classification',
#  'A Nested HDP for Hierarchical Topic Models',
#  'Indoor Semantic Segmentation using depth information',
#  'Saturating Auto-Encoder',
#  'Big Neural Networks Waste Capacity',
#  'Natural Gradient Revisited',
#  'Tree structured sparse coding on cubes',
#  'Deep Learning for Detecting Robotic Grasps',
#  'Feature Learning in Deep Neural Networks - A Study on Speech Recognition Tasks',
#  'Jitter-Adaptive Dictionary Learning - Application to Multi-Trial Neuroelectric Signals',
#  'Learning New Facts From Knowledge Bases With Neural Tensor Networks and Semantic Word Vectors',
#  'Two SVDs produce more focal deep learning representations',
#  'Training Neural Networks with Stochastic Hessian-Free Optimization',
#  'Regularized Discriminant Embedding for Visual Descriptor Learning',
#  'Zero-Shot Learning Through Cross-Modal Transfer',
#  'Gradient Driven Learning for Pooling in Visual Pipeline Feature Extraction Models',
#  'Adaptive learning rates and parallelization for stochastic, sparse, non-smooth gradients',
#  'Discriminative Recurrent Sparse Auto-Encoders',
#  'Efficient Estimation of Word Representations in Vector Space',
#  'Knowledge Matters: Importance of Prior Information for Optimization',
#  'Herded Gibbs Sampling',
#  'Affinity Weighted Embedding',
#  'Latent Relation Representations for Universal Schemas',
#  'Why Size Matters: Feature Coding as Nystrom Sampling',
#  'Hierarchical Data Representation Model - Multi-layer NMF',
#  '1st International Conference on Learning Representations, ICLR 2013, Scottsdale, Arizona, USA, May 2-4, 2013, Conference Track Proceedings',
#  '1st International Conference on Learning Representations, ICLR 2013, Scottsdale, Arizona, USA, May 2-4, 2013, Workshop Track Proceedings']

# %%
links = [url['info']['ee'] for url in data_json['result']['hits']['hit']][:-1]
titles = [title['info']['title'] for title in data_json['result']['hits']['hit']][:-1]
conference, _, _, _, _, date, year, _ = titles[-1].split(',')
titles.pop(-1)
links.pop(-1)
print(conference)
print(date)
print(year)
# Out:
# 1st International Conference on Learning Representations
#  May 2-4
#  2013

# %%
# Scrapper OpenReview

pbar = pbar = tqdm.tqdm(total= len(links))
for name, url in zip(titles,links):
    page = requests.get(url).content.decode('utf-8')
    soup = BeautifulSoup(page, 'lxml')

    try:
        authors = [author['content'] for author in soup.find_all('meta', {'name': 'citation_author'})]
    except:
        authors = []
    try:
        abstract = soup.find('meta', {'name': 'citation_abstract'})['content'].replace('\n', ' ')
    except:
        abstract = ''

    df = df.append({
        'title': name, 
        'authors': authors,
        'conference': conference,
        'abstract': abstract,
        'date': date,
        'year':year}, ignore_index=True)
    pbar.update(1)
pbar.close()

df
# Out:
# 100%|██████████| 55/55 [01:06<00:00,  1.21s/it]
#                                                 title  \
# 0                            Local Component Analysis
# 1   When Does a Mixture of Products Contain a Prod...
# 2   Linear-Nonlinear-Poisson Neurons Can Do Infere...
# 3   Regularized Auto-Encoders Estimate Local Stati...
# 4   Visual Objects Classification with Sliding Spa...
# 5                 Cutting Recursive Autoencoder Trees
# 6              Clustering Learning for Robotic Vision
# 7   Unsupervised Feature Learning for low-level Lo...
# 8   Matrix Approximation under Local Low-Rank Assu...
# 9                      The Manifold of Human Emotions
# 10  Efficient Learning of Domain-invariant Image R...
# 11  Auto-pooling: Learning to Improve Invariance o...
# 12                                     Barnes-Hut-SNE
# 13  The Diagonalized Newton Algorithm for Nonnegat...
# 14  Feature grouping from spatially constrained mu...
# 15                            Factorized Topic Models
# 16  Boltzmann Machines and Denoising Autoencoders ...
# 17  Pushing Stochastic Gradient towards Second-Ord...
# 18  A Semantic Matching Energy Function for Learni...
# 19  Learnable Pooling Regions for Image Classifica...
# 20            Block Coordinate Descent for Sparse NMF
# 21             Discrete Restricted Boltzmann Machines
# 22  The Neural Representation Benchmark and its Ev...
# 23  Learning Stable Group Invariant Representation...
# 24  Learning Features with Structure-Adapting Mult...
# 25                    Deep Predictive Coding Networks
# 26  Metric-Free Natural Gradient for Joint-Trainin...
# 27  Information Theoretic Learning with Infinitely...
# 28  Stochastic Pooling for Regularization of Deep ...
# 29  Complexity of Representation and Inference in ...
# 30  Joint Training Deep Boltzmann Machines for Cla...
# 31         A Nested HDP for Hierarchical Topic Models
# 32  Indoor Semantic Segmentation using depth infor...
# 33                            Saturating Auto-Encoder
# 34                 Big Neural Networks Waste Capacity
# 35                         Natural Gradient Revisited
# 36             Tree structured sparse coding on cubes
# 37         Deep Learning for Detecting Robotic Grasps
# 38  Feature Learning in Deep Neural Networks - A S...
# 39  Jitter-Adaptive Dictionary Learning - Applicat...
# 40  Learning New Facts From Knowledge Bases With N...
# 41  Two SVDs produce more focal deep learning repr...
# 42  Training Neural Networks with Stochastic Hessi...
# 43  Regularized Discriminant Embedding for Visual ...
# 44    Zero-Shot Learning Through Cross-Modal Transfer
# 45  Gradient Driven Learning for Pooling in Visual...
# 46  Adaptive learning rates and parallelization fo...
# 47      Discriminative Recurrent Sparse Auto-Encoders
# 48  Efficient Estimation of Word Representations i...
# 49  Knowledge Matters: Importance of Prior Informa...
# 50                              Herded Gibbs Sampling
# 51                        Affinity Weighted Embedding
# 52  Latent Relation Representations for Universal ...
# 53  Why Size Matters: Feature Coding as Nystrom Sa...
# 54  Hierarchical Data Representation Model - Multi...
#
#                                               authors  \
# 0                   [Roux, Nicolas Le, Bach, Francis]
# 1                 [Montufar, Guido F., Morton, Jason]
# 2                              [Shao, Louis Yuanlong]
# 3                  [Alain, Guillaume, Bengio, Yoshua]
# 4                     [Lim, Hao Wooi, Tay, Yong Haur]
# 5            [Scheible, Christian, Schuetze, Hinrich]
# 6   [Culurciello, Eugenio, Bates, Jordan, Dundar, ...
# 7   [Osendorfer, Christian, Bayer, Justin, Urban, ...
# 8   [Lee, Joonseok, Kim, Seungyeon, Lebanon, Guy, ...
# 9   [Kim, Seungyeon, Li, Fuxin, Lebanon, Guy, Essa...
# 10  [Hoffman, Judy, Rodner, Erik, Donahue, Jeff, D...
# 11  [Sukhbaatar, Sainbayar, Makino, Takaki, Aihara...
# 12                          [van der Maaten, Laurens]
# 13                                  [Van hamme, Hugo]
# 14                  [Bauer, Felix, Memisevic, Roland]
# 15  [Zhang, Cheng, Ek, Carl Henrik, Damianou, Andr...
# 16                                   [Cho, Kyunghyun]
# 17  [Vatanen, Tommi, Raiko, Tapani, Valpola, Harri...
# 18  [Glorot, Xavier, Bordes, Antoine, Weston, Jaso...
# 19                [Malinowski, Mateusz, Fritz, Mario]
# 20  [Potluru, Vamsi K., Plis, Sergey M., Roux, Jon...
# 21                   [Montufar, Guido, Morton, Jason]
# 22  [Cadieu, Charles F., Hong, Ha, Yamins, Dan, Pi...
# 23          [Bruna, Joan, Szlam, Arthur, LeCun, Yann]
# 24                   [Kang, Yoonseop, Choi, Seungjin]
# 25             [Chalasani, Rakesh, Principe, Jose C.]
# 26  [Desjardins, Guillaume, Pascanu, Razvan, Courv...
# 27      [Giraldo, Luis G. Sanchez, Principe, Jose C.]
# 28                  [Zeiler, Matthew D., Fergus, Rob]
# 29               [Yuille, Alan L., Mottaghi, Roozbeh]
# 30  [Goodfellow, Ian J., Courville, Aaron, Bengio,...
# 31  [Paisley, John, Wang, Chong, Blei, David, Jord...
# 32  [Couprie, Camille, Farabet, Clément, Najman, L...
# 33                 [Goroshin, Rostislav, LeCun, Yann]
# 34                 [Dauphin, Yann N., Bengio, Yoshua]
# 35                  [Pascanu, Razvan, Bengio, Yoshua]
# 36                                    [Szlam, Arthur]
# 37        [Lenz, Ian, Lee, Honglak, Saxena, Ashutosh]
# 38  [Yu, Dong, Seltzer, Michael L., Li, Jinyu, Hua...
# 39  [Hitziger, Sebastian, Clerc, Maureen, Gramfort...
# 40  [Chen, Danqi, Socher, Richard, Manning, Christ...
# 41           [Schuetze, Hinrich, Scheible, Christian]
# 42                                      [Kiros, Ryan]
# 43  [Kim, Kye-Hyeon, Cai, Rui, Zhang, Lei, Choi, S...
# 44  [Socher, Richard, Ganjoo, Milind, Sridhar, Ham...
# 45                        [Rose, Derek, Arel, Itamar]
# 46                         [Schaul, Tom, LeCun, Yann]
# 47                  [Rolfe, Jason Tyler, LeCun, Yann]
# 48  [Mikolov, Tomas, Chen, Kai, Corrado, Greg, Dea...
# 49                 [Gülçehre, Çağlar, Bengio, Yoshua]
# 50  [Bornn, Luke, Chen, Yutian, de Freitas, Nando,...
# 51           [Weston, Jason, Weiss, Ron, Yee, Hector]
# 52  [Riedel, Sebastian, Yao, Limin, McCallum, Andrew]
# 53   [Vinyals, Oriol, Jia, Yangqing, Darrell, Trevor]
# 54                    [Song, Hyun Ah, Lee, Soo-Young]
#
#                                            conference  \
# 0   1st International Conference on Learning Repre...
# 1   1st International Conference on Learning Repre...
# 2   1st International Conference on Learning Repre...
# 3   1st International Conference on Learning Repre...
# 4   1st International Conference on Learning Repre...
# 5   1st International Conference on Learning Repre...
# 6   1st International Conference on Learning Repre...
# 7   1st International Conference on Learning Repre...
# 8   1st International Conference on Learning Repre...
# 9   1st International Conference on Learning Repre...
# 10  1st International Conference on Learning Repre...
# 11  1st International Conference on Learning Repre...
# 12  1st International Conference on Learning Repre...
# 13  1st International Conference on Learning Repre...
# 14  1st International Conference on Learning Repre...
# 15  1st International Conference on Learning Repre...
# 16  1st International Conference on Learning Repre...
# 17  1st International Conference on Learning Repre...
# 18  1st International Conference on Learning Repre...
# 19  1st International Conference on Learning Repre...
# 20  1st International Conference on Learning Repre...
# 21  1st International Conference on Learning Repre...
# 22  1st International Conference on Learning Repre...
# 23  1st International Conference on Learning Repre...
# 24  1st International Conference on Learning Repre...
# 25  1st International Conference on Learning Repre...
# 26  1st International Conference on Learning Repre...
# 27  1st International Conference on Learning Repre...
# 28  1st International Conference on Learning Repre...
# 29  1st International Conference on Learning Repre...
# 30  1st International Conference on Learning Repre...
# 31  1st International Conference on Learning Repre...
# 32  1st International Conference on Learning Repre...
# 33  1st International Conference on Learning Repre...
# 34  1st International Conference on Learning Repre...
# 35  1st International Conference on Learning Repre...
# 36  1st International Conference on Learning Repre...
# 37  1st International Conference on Learning Repre...
# 38  1st International Conference on Learning Repre...
# 39  1st International Conference on Learning Repre...
# 40  1st International Conference on Learning Repre...
# 41  1st International Conference on Learning Repre...
# 42  1st International Conference on Learning Repre...
# 43  1st International Conference on Learning Repre...
# 44  1st International Conference on Learning Repre...
# 45  1st International Conference on Learning Repre...
# 46  1st International Conference on Learning Repre...
# 47  1st International Conference on Learning Repre...
# 48  1st International Conference on Learning Repre...
# 49  1st International Conference on Learning Repre...
# 50  1st International Conference on Learning Repre...
# 51  1st International Conference on Learning Repre...
# 52  1st International Conference on Learning Repre...
# 53  1st International Conference on Learning Repre...
# 54  1st International Conference on Learning Repre...
#
#                                              abstract      date   year
# 0    Kernel density estimation, a.k.a. Parzen wind...   May 2-4   2013
# 1    We derive relations between theoretical prope...   May 2-4   2013
# 2    One conjecture in both deep learning and clas...   May 2-4   2013
# 3    What do auto-encoders learn about the underly...   May 2-4   2013
# 4    We present a method for visual object classif...   May 2-4   2013
# 5    Deep Learning models enjoy considerable succe...   May 2-4   2013
# 6    We present the clustering learning technique ...   May 2-4   2013
# 7    Unsupervised feature learning has shown impre...   May 2-4   2013
# 8    Matrix approximation is a common tool in mach...   May 2-4   2013
# 9    Sentiment analysis predicts the presence of p...   May 2-4   2013
# 10   We present an algorithm that learns represent...   May 2-4   2013
# 11   Learning invariant representations from image...   May 2-4   2013
# 12   The paper presents an O(N log N)-implementati...   May 2-4   2013
# 13   Non-negative matrix factorization (NMF) has b...   May 2-4   2013
# 14   We present a feature learning model that lear...   May 2-4   2013
# 15   In this paper we present a modification to a ...   May 2-4   2013
# 16   Image denoising based on a probabilistic mode...   May 2-4   2013
# 17   Recently, we proposed to transform the output...   May 2-4   2013
# 18   Large-scale relational learning becomes cruci...   May 2-4   2013
# 19   Biologically inspired, from the early HMAX mo...   May 2-4   2013
# 20   Nonnegative matrix factorization (NMF) has be...   May 2-4   2013
# 21   We describe discrete restricted Boltzmann mac...   May 2-4   2013
# 22   A key requirement for the development of effe...   May 2-4   2013
# 23   Transformation groups, such as translations o...   May 2-4   2013
# 24   We proposea graphical model for multi-view fe...   May 2-4   2013
# 25   The quality of data representation in deep le...   May 2-4   2013
# 26   This paper introduces the Metric-Free Natural...   May 2-4   2013
# 27   In this paper, we develop a framework for inf...   May 2-4   2013
# 28   We introduce a simple and effective method fo...   May 2-4   2013
# 29   This paper describes serial and parallel comp...   May 2-4   2013
# 30   We introduce a new method for training deep B...   May 2-4   2013
# 31   We develop a nested hierarchical Dirichlet pr...   May 2-4   2013
# 32   This work addresses multi-class segmentation ...   May 2-4   2013
# 33   We introduce a simple new regularizer for aut...   May 2-4   2013
# 34   This article exposes the failure of some big ...   May 2-4   2013
# 35   The aim of this paper is three-fold. First we...   May 2-4   2013
# 36   A brief description of tree structured sparse...   May 2-4   2013
# 37   We consider the problem of detecting robotic ...   May 2-4   2013
# 38   Recent studies have shown that deep neural ne...   May 2-4   2013
# 39   Dictionary Learning has proven to be a powerf...   May 2-4   2013
# 40   Knowledge bases provide applications with the...   May 2-4   2013
# 41   A key characteristic of work on deep learning...   May 2-4   2013
# 42   Hessian-free (HF) optimization has been succe...   May 2-4   2013
# 43   Images can vary according to changes in viewp...   May 2-4   2013
# 44   This work introduces a model that can recogni...   May 2-4   2013
# 45   Hyper-parameter selection remains a daunting ...   May 2-4   2013
# 46   Recent work has established an empirically su...   May 2-4   2013
# 47   We present the discriminative recurrent spars...   May 2-4   2013
# 48   We propose two novel model architectures for ...   May 2-4   2013
# 49   We explore the effect of introducing prior in...   May 2-4   2013
# 50   The Gibbs sampler is one of the most popular ...   May 2-4   2013
# 51   Supervised (linear) embedding models like Wsa...   May 2-4   2013
# 52   Traditional relation extraction predicts rela...   May 2-4   2013
# 53   Recently, the computer vision and machine lea...   May 2-4   2013
# 54   In this paper, we propose a data representati...   May 2-4   2013

# %%
df.to_csv(f'./iclr/ICLR_{year}.csv', index=False)

# %%
# join all csvs in a folder

path = r'./iclr'
all_files = glob.glob(os.path.join(path, "*.csv"))

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

# save to csv
frame = pd.concat(li, axis=0, ignore_index=True)
frame['authors'] = frame['authors'].apply(lambda x: '; '.join(eval(x)))
frame['date'] = frame['date'].apply(lambda x: re.sub('[^A-Za-z]+', '', x).upper())
frame.columns = ['Article Title', 'Author Full Names', 'Conference Title', 'Abstract', 'Publication Date', 'Publication Year']
frame['Source Title'] = ['INTERNATIONAL CONFERENCE ON LEARNING REPRESENTATIONS']*len(frame)
frame['Publication Type'] = ['C']*len(frame)

frame.to_csv('./venues/ICLR.csv', index=False)
