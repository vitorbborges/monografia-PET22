# %%
import pandas as pd
import os
import numpy as np

# %%
partial_folder = 'C:/Users/vitor/Desktop/Education/PET/Monografia/Dados/parciais/'
df=pd.DataFrame()

t_abs = 0

for i in os.listdir(partial_folder):
    dfp = pd.read_excel(partial_folder + i)
    df = pd.concat([df,dfp])
    print(i)
    t_abs += len(dfp['Abstract'].dropna())
    print(len(dfp['Abstract'].dropna()))

print(t_abs)
df.to_excel('journals.xls')
# Out:
# savedrecs (1).xls
# 988
# savedrecs (10).xls
# 984
# savedrecs (11).xls
# 983
# savedrecs (12).xls
# 989
# savedrecs (13).xls
# 982
# savedrecs (14).xls
# 990
# savedrecs (15).xls
# 979
# savedrecs (16).xls
# 984
# savedrecs (17).xls
# 982
# savedrecs (18).xls
# 984
# savedrecs (19).xls
# 969
# savedrecs (2).xls
# 989
# savedrecs (20).xls
# 979
# savedrecs (21).xls
# 976
# savedrecs (22).xls
# 978
# savedrecs (23).xls
# 969
# savedrecs (24).xls
# 972
# savedrecs (25).xls
# 975
# savedrecs (26).xls
# 962
# savedrecs (27).xls
# 970
# savedrecs (28).xls
# 965
# savedrecs (29).xls
# 957
# savedrecs (3).xls
# 984
# savedrecs (30).xls
# 981
# savedrecs (31).xls
# 979
# savedrecs (32).xls
# 969
# savedrecs (33).xls
# 978
# savedrecs (34).xls
# 974
# savedrecs (35).xls
# 962
# savedrecs (36).xls
# 962
# savedrecs (37).xls
# 966
# savedrecs (38).xls
# 950
# savedrecs (39).xls
# 985
# savedrecs (4).xls
# 983
# savedrecs (40).xls
# 959
# savedrecs (41).xls
# 923
# savedrecs (42).xls
# 962
# ...

# %%
i = 1
df = pd.read_excel(partial_folder + os.listdir(partial_folder)[i])
print(len(df['Abstract'].dropna()))
#df.iloc[np.where(df['Abstract'].isna())]
# Out:
# 984
#     Publication Type                                            Authors  \
# 27                 J                     Xiao, J; Kroeger, T; Khatib, O
# 152                J                                          Abbass, H
# 264                J           Xue, JH; Ma, ZY; Roveri, M; Japkowicz, N
# 357                J         Togacar, M; Comert, Z; Ergen, B; Ozyurt, F
# 371                J  Liu, L; Pietikainen, M; Qin, J; Ouyang, WL; Va...
# 402                J         Chakrabarti, A; Sunkavalli, K; Forsyth, DA
# 426                J                                          Flach, PA
# 555                J                             Kazakov, D; Aelezny, F
# 619                J          Kida, T; Kuboyama, T; Uno, T; Yamamoto, A
# 626                J  Sechidis, K; Azzimonti, L; Pocock, A; Corani, ...
# 750                J                                          Sahin, GG
# 828                J  Miller-Jackson, T; Sun, Y; Natividad, R; Yeow, CH
# ...

# %%
df.iloc[np.where(df['Abstract'].isna())]
# Out:
#     Publication Type                                            Authors  \
# 46                 J                 Gammerman, A; Vovk, V; Cristani, M
# 103                J           Pang, GS; Aggarwal, C; Shen, CH; Sebe, N
# 134                J  TANAKA, G; GALLICCHIO, C; MICHELI, A; ORTEGA, ...
# 294                J                       Patsantzis, S; Muggleton, SH
# 393                J                                   Yang, X; Yan, JC
# 476                J               Jiang, YX; Wu, Q; Zhu, SK; Zhang, LK
# 483                J                                          Keller, J
# 550                J               Song, YD; Si, J; Coleman, S; Kerr, D
# 555                J                                           Ting, CK
# 701                J  Xiao, TH; Liu, SF; De Mello, S; Yu, ZD; Kautz,...
# 749                J  Caraffini, F; Chiclana, F; Moodley, R; Gongora, M
# 978                J          Wang, M; Zhang, C; Hao, SJ; Yu, J; Mu, TT
#
# ...

# %%
df.iloc[np.where(df['Date of Export'].value_counts() > 1)]
# Out:
#   Publication Type                       Authors  Book Authors Book Editors  \
# 0                J  Liu, JY; Zhang, JG; Wang, YC           NaN          NaN
#
#    Book Group Authors                          Author Full Names  \
# 0                 NaN  Liu, Jiayue; Zhang, Jianguo; Wang, Yuncai
#
#    Book Author Full Names Group Authors  \
# 0                     NaN           NaN
#
#                                        Article Title  \
# 0  Secure Communication via Chaotic Synchronizati...
#
#                                         Source Title  ...  \
# 0  IEEE TRANSACTIONS ON NEURAL NETWORKS AND LEARN...  ...
#
#                              Web of Science Index  \
# 0  Science Citation Index Expanded (SCI-EXPANDED)
#
#                   Research Areas IDS Number   Pubmed Id  \
# 0  Computer Science; Engineering      2A2XU  35653446.0
#
#   Open Access Designations Highly Cited Status Hot Paper Status  \
# 0                      NaN                 NaN              NaN
#
# ...

# %%
np.where(df['Date of Export'].value_counts() > 1)
# Out:
# (array([0], dtype=int64),)

# %%
max(df['Publication Year'].value_counts().index)
# Out:
# 2022.0

# %%
df['Publication Year'].value_counts().index
# Out:
# Float64Index([2021.0, 2020.0, 2022.0, 2012.0, 2011.0, 2018.0, 2019.0, 2009.0,
#               2015.0, 2017.0, 2016.0, 2010.0, 2014.0, 2013.0, 2008.0, 2007.0,
#               2006.0, 2005.0, 2004.0, 2003.0, 2002.0, 2001.0, 1998.0, 1996.0,
#               1999.0, 1997.0, 2000.0, 1995.0, 1992.0, 1994.0, 1993.0, 1991.0,
#               1990.0, 1989.0, 1988.0, 1987.0, 1984.0, 1986.0, 1981.0, 1983.0,
#               1985.0, 1982.0, 1980.0, 1979.0, 1978.0, 1976.0, 1971.0, 1973.0,
#               1972.0, 1977.0, 1975.0, 1970.0, 1974.0, 1969.0, 1968.0],
#              dtype='float64')
